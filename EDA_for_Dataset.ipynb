# %% [markdown]
# **Instructions**
# 1. Follow the instructions in each of the cell
# 2. Make sure not to delete any of the cells

# %%
#import statements
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_selection import f_regression
import pickle
import hashlib

# %% [markdown]
# ### Input Data

# %%
#Load and print the data
data=pd.read_csv('./input/input.csv')
#Enter the answer here
data
# Out:
#      school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0        GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1        GP   F   17       U     GT3       T     1     1   at_home     other
# 2        GP   F   15       U     LE3       T     1     1   at_home     other
# 3        GP   F   15       U     GT3       T     4     2    health  services
# 4        GP   F   16       U     GT3       T     3     3     other     other
# 5        GP   M   16       U     LE3       T     4     3  services     other
# 6        GP   M   16       U     LE3       T     2     2     other     other
# 7        GP   F   17       U     GT3       A     4     4     other   teacher
# 8        GP   M   15       U     LE3       A     3     2  services     other
# 9        GP   M   15       U     GT3       T     3     4     other     other
# 10       GP   F   15       U     GT3       T     4     4   teacher    health
# ...

# %% [markdown]
# ### Data Cleaning
#
# Check if there are any null values in data.
#
# If so, replace the null values with column mean

# %%
data.isnull().values.any()
# Out:
# False

# %% [markdown]
# ### Exploratory Data Analysis

# %% [markdown]
# **Question:1**
#
# Which school has more number of students? Gabriel Pereira or Mousinho da Silveira
#
# Assign the number of students in that school to the variable **q1**

# %%
#a=data.groupby(["school"]).count().max(level=0)
#print(a)
#Enter the answer here
q1=772

# %% [markdown]
# **Question 2:**
#
# Which group of students have more opportunity in schooling? Rural or Urban?
#
# Assign the number of rural students or the number of urban students who has more opportunity to **q2**

# %%
#b=data.groupby(["address"]).count().max(level=0)
#print(b)
#Enter the answer here
q2=759

# %% [markdown]
# **Question 3**
#
# Which group of students(rural or urban) shows more interest in each of the schools?
#
# *Instructions*
# 1. Find the number of rural and Urban areas students in each school and find the greatest among them.
# 2. Store them in respective variable

# %%
#c=data.groupby(["school","address"]).count()
#print(c)


#Store the number of rural students or the number of urban students who had more opportunity to study in GP school
#Enter the answer here
q3=631


#Store the number of rural students or the number of urban students who had more opportunity to study in GP school
#Enter the answer here
q4=144

# %% [markdown]
# **Question 4**
#
# Which age group of students are more interested in GP school? Assign the specific age to the variable.

# %%
#d=data[data.school=='GP'].groupby(["age"]).count()
#print(d)


#Enter the answer here
q5=16

# %% [markdown]
# **Question 5**
#
# Find out the average Daily consumption of alcohol in rural area and Urban area separately.

# %%
#data[data.address=='R'].Dalc.mean()
#Average Daily Consumption of Alcohol in Rural Area

#Enter the answer here
q6=1.5894736842105264

#print(q6)

#Average Daily Consumption of Alcohol in Urban Area

#Enter the answer here
q7=1.458498023715415
#data[data.address=='U'].Dalc.mean()
#print(q7)

# %% [markdown]
# **Question 6**
#
# Find out the average Daily consumption of alcohol in rural areas and Urban areas separately specific to each school and assign the greater average value to the respective variable of schools.

# %%
#f=data.groupby(["school","address"]).Dalc.mean()
#GP school greater average in rural or urban
#print(f)
#Enter the answer here
q8=1.517730



#MS school greater average in rural or urban

#Enter the answer here
q9=1.659722

#print(data.dtypes)

# %% [markdown]
# **Question 7**
#
# **Let us find the variable which made the maximum impact on the Final grade of students with pearson coefficient.**
#
# *Note: All the variables used for calculating pearson coefficient must be numerical.*
#
#
#
# A predictor that has a low p-value is likely to be a meaningful addition to your model because changes in the predictor's value are related to changes in the response variable.
#
# Conversely, a larger (insignificant) p-value suggests that changes in the predictor are not associated with changes in the response.
#
#
# *Instructions*
# 1. Consider G3 as target variable `Y`.
# 2. Remove the variables G1, G2. Consider the rest as predictor variables
# 3. Calculate the P value of all variables (hint: fregression and label encoding using cat.codes)
# 4. Variables with P-values less than 0.05 (95% confidence) are considered to be the `Predictor Variables`. Form a dataframe `X` with it.
# 5. Calculate the correlation between the predictor variable and target variable
# 6. Find the highest Correlation value in the column `G3` which depicts the variable that made the greatest impact on G3.
# 7. Print the variable that made greatest impact on `G3`.
# 8. Assign the highest correlation value and the highest impacted attribute to the respective variable
#
# Note: Make sure to compare the absolute value of the correlation values

# %%
'''from sklearn.preprocessing import LabelEncoder
from scipy.stats import pearsonr
Y=data.G3
data2=data
X=data[:-3]

print(data.corr())

col=['school','sex','address', 'famsize','Pstatus', 'Mjob','Fjob', 'reason','guardian','schoolsup','famsup', 'paid','activities','nursery','higher','internet','romantic']  
for name in col:
    X[name] = LabelEncoder().fit_transform(X[name])
print(X.data_corr())

f,p=f_regression(X,Y)
print(f)
print(p)
#for colname in X.columns:
    #print(colname)
    #print(pearsonr(X[colname],Y)) '''
#Highest impact attribute
#higher (0.23657799566492788, 9.549431631711794e-15)
#Enter the answer here
q10='failures'



#highest correlation value

#Enter the answer here
q11=0.383145

# %% [markdown]
# ## Run the below cells to save your answers in pickle file

# %%
def make_pickle1(file_name, obj):
    with open(file_name, 'wb') as f:
        pickle.dump(geth(obj), f, pickle.HIGHEST_PROTOCOL)

# %%
def make_pickle2(file_name, obj):
    with open(file_name, 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

# %%
def get_pickle(file_name):
    with open(file_name, 'rb') as f:
        return pickle.load(f)

# %%
def geth(obj):
    obj = str(obj).encode()
    m = hashlib.md5()
    m.update( bytes(obj) )
    return m.hexdigest()

# %%
def pickling():
    make_pickle1('q1.pickle', q1)
    make_pickle1('q2.pickle', q2)
    make_pickle1('q3.pickle', q3)
    make_pickle1('q4.pickle', q4)
    make_pickle1('q5.pickle', q5)
    make_pickle2('q6.pickle', q6)
    make_pickle2('q7.pickle', q7)
    make_pickle2('q8.pickle', q8)
    make_pickle2('q9.pickle', q9)
    make_pickle1('q10.pickle', q10)
    make_pickle2('q11.pickle', q11)
    
    
pickling()
